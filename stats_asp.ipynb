# %%
import seaborn as sns
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(palette=['#8cb369', '#493c67'])
species = ('gender', 'age group', 'dialect')
penguin_means = {
    'wav2vec': (0.9268292682926829, 0.8228253266949567, 0.7857019183280752),
    'whisper': (0.9483568075117371, 0.7007911925566983, 0.8447011560922001),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1 score')
ax.set_xticks(x + 0.5*width, species)
#ax.set_xticklabels(species, ha='center')
ax.legend(loc='upper right', ncols=3)
#ax.set_ylim(0, 250)

plt.savefig('rq1_f1.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(palette=['#8cb369', '#493c67'])


species = ('gender', 'age group', 'dialect')
penguin_means = {
    'wav2vec': (0.9308943089430894, 0.8103448275862069, 0.7848180677540778),
    'whisper': (0.9679802955665024, 0.5714285714285714, 0.8725674827369743),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MLP score')
ax.set_xticks(x + 0.5*width, species)
#ax.set_xticklabels(species, ha='center')
ax.legend(loc='upper right', ncols=3)
#ax.set_ylim(0, 250)

plt.savefig('rq1_mlp.png')
plt.show()

# %%
n_ft = {1: 0.8911076975593104,
2: 0.8789217744831321,
 3: 0.8838637428715758,
 4: 0.874108527131783,
 5: 0.8443279957640271,
 6: 0.8138878192786548,
 7: 0.8146941997878272,
 8: 0.7906445672191529,
 9: 0.7846446105642316,
 10: 0.7882653217741293,
 11: 0.8012142577359969,
 12: 0.7601949154628012,
 13: 0.7766900890545142,
 14: 0.7643033596837945,
 15: 0.7813356835095966,
 16: 0.7806752608962555,
 17: 0.7927896351774306,
 18: 0.7899172087522176,
 19: 0.8006138735420503,
 20: 0.8277407810511169,
 21: 0.8113244466185643,
 22: 0.81834451901566,
 23: 0.7457826887661141,
 24: 0.7543319214478243,
 25: 0.7962446141793968}

ft = {1: 0.8756401774118454,
 2: 0.8963000802743923,
 3: 0.893618188133352,
 4: 0.8782995956370399,
 5: 0.8734437171094853,
 6: 0.8560107618931148,
 7: 0.8358450341836359,
 8: 0.8120683589772075,
 9: 0.8073042191882147,
 10: 0.8020453381226585,
 11: 0.7846446105642315,
 12: 0.7733756729266417,
 13: 0.7893774703557311,
 14: 0.7817082893004802,
 15: 0.80798594689548,
 16: 0.8257211538461539,
 17: 0.7828035934992343,
 18: 0.8129733248981947,
 19: 0.8504604051565376,
 20: 0.823494473869516,
 21: 0.8831583136882712,
 22: 0.8711205528288526,
 23: 0.7465808875787183,
 24: 0.7311541151206471,
 25: 0.8111535448491971}

to_graph = pd.DataFrame.from_dict(n_ft, orient='index', columns = ['w2v'])
to_graph['w2v-ru'] = ft.values()

gfg = sns.lineplot(data=to_graph, palette=['#8cb369', '#493c67'])
sns.set_theme()
gfg.set(xlabel ="Layer", ylabel = "F1")
plt.savefig('rq2_gender.png')

# %%
n_ft = {1: 0.7419556250462026,
 2: 0.7262285620067374,
 3: 0.7173426044393786,
 4: 0.691635538033843,
 5: 0.6398179690076152,
 6: 0.6593887222528593,
 7: 0.6242575499587936,
 8: 0.6150290075662322,
 9: 0.6159961424034703,
 10: 0.587775849243739,
 11: 0.610801531914659,
 12: 0.6179747102769199,
 13: 0.6129506671625103,
 14: 0.5801262612856816,
 15: 0.5908011252228734,
 16: 0.6043327819887551,
 17: 0.6174998293199131,
 18: 0.6149949446897559,
 19: 0.6494656810479477,
 20: 0.6509944412022349,
 21: 0.7280685900151508,
 22: 0.6733002212778513,
 23: 0.5550794823405364,
 24: 0.5818556887699012,
 25: 0.6615973726826867}

ft = {1: 0.7053295024800654,
 2: 0.7078831578201848,
 3: 0.7036576521957626,
 4: 0.708778328880261,
 5: 0.661986726145142,
 6: 0.6689360123018032,
 7: 0.6450298472053911,
 8: 0.6295205230187589,
 9: 0.6352097027478291,
 10: 0.6349222055883444,
 11: 0.6324125192845802,
 12: 0.59587845073281,
 13: 0.6068575236969019,
 14: 0.594302501990451,
 15: 0.5574209105558593,
 16: 0.5862752504056852,
 17: 0.5994668563663991,
 18: 0.5755100731646129,
 19: 0.608041464696431,
 20: 0.6166896120036035,
 21: 0.6148007837691399,
 22: 0.5946921644073068,
 23: 0.5630080141862267,
 24: 0.5510373939670531,
 25: 0.5625568091987229}

to_graph = pd.DataFrame.from_dict(n_ft, orient='index', columns = ['w2v'])
to_graph['w2v-ru'] = ft.values()

gfg = sns.lineplot(data=to_graph, palette=['#8cb369', '#493c67'])
sns.set_theme()
gfg.set(xlabel ="Layer", ylabel = "F1")
plt.savefig('rq2_age.png')

# %%
n_ft = {1: 0.7310413737996224,
 2: 0.7252591440123041,
 3: 0.7084645373300836,
 4: 0.6954856174816803,
 5: 0.7204845779217296,
 6: 0.691331170736205,
 7: 0.6892166904292183,
 8: 0.653625220264392,
 9: 0.6863528727971233,
 10: 0.6501539715994165,
 11: 0.6612683132139305,
 12: 0.6290134136219768,
 13: 0.6449607167266236,
 14: 0.6372013893016077,
 15: 0.6339760541897919,
 16: 0.654259324102158,
 17: 0.6463188930269599,
 18: 0.6534824548599878,
 19: 0.645598666043564,
 20: 0.6802289252338167,
 21: 0.6786609001949239,
 22: 0.6867477838041556,
 23: 0.6094180249502945,
 24: 0.60633056279608,
 25: 0.6560821898884268}

ft = {1: 0.7404827747454307,
 2: 0.7273356407609679,
 3: 0.7135129409463941,
 4: 0.6796781119766346,
 5: 0.7003028329148704,
 6: 0.6878255338996329,
 7: 0.6834454390574517,
 8: 0.6755773754056418,
 9: 0.6535704690272235,
 10: 0.6273594664899013,
 11: 0.6306182740200947,
 12: 0.6281262722172316,
 13: 0.6203109124161755,
 14: 0.6234920233275496,
 15: 0.6342084464713491,
 16: 0.6202647938567977,
 17: 0.6000363608421104,
 18: 0.6301106737111088,
 19: 0.6257562138919239,
 20: 0.5705374895130864,
 21: 0.5594917012063675,
 22: 0.5601006879822672,
 23: 0.5478886451806344,
 24: 0.5454340246912044,
 25: 0.5409260184918929}

to_graph = pd.DataFrame.from_dict(n_ft, orient='index', columns = ['w2v'])
to_graph['w2v-ru'] = ft.values()

gfg = sns.lineplot(data=to_graph, palette=['#8cb369', '#493c67'])
sns.set_theme()
gfg.set(xlabel ="Layer", ylabel = "F1")
plt.savefig('rq2_dialects.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(palette=['#92aa83', '#493c67', '#adb5bd'])
species = ('gender', 'age group', 'dialect')
penguin_means = {
    'wav2vec': (0.9268292682926829, 0.8228253266949567, 0.7857019183280752),
    'wav2vec-ru': (0.9090909090909092, 0.8045057172476753, 0.7859773685441035),
    'whisper': (0.9483568075117371, 0.7007911925566983, 0.8447011560922001),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1 score')
ax.set_xticks(x + 0.5*width, species)
#ax.set_xticklabels(species, ha='center')
ax.legend(loc='upper right', ncols=3)
#ax.set_ylim(0, 250)

plt.savefig('rq3_f1.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(palette=['#92aa83', '#493c67', '#adb5bd'])


species = ('gender', 'age group', 'dialect')
penguin_means = {
    'wav2vec': (0.9308943089430894, 0.8103448275862069, 0.7848180677540778),
    'wav2vec-ru': (0.9236453201970444, 0.8103448275862069, 0.7772898368883312),
    'whisper': (0.9679802955665024, 0.5714285714285714, 0.8725674827369743),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MLP score')
ax.set_xticks(x + 0.5*width, species)
#ax.set_xticklabels(species, ha='center')
ax.legend(loc='upper right', ncols=3)
#ax.set_ylim(0, 250)

plt.savefig('rq3_mlp.png')
plt.show()

# %%
n_ft = {1: 0.8911076975593104,
2: 0.8789217744831321,
 3: 0.8838637428715758,
 4: 0.874108527131783,
 5: 0.8443279957640271,
 6: 0.8138878192786548,
 7: 0.8146941997878272,
 8: 0.7906445672191529,
 9: 0.7846446105642316,
 10: 0.7882653217741293,
 11: 0.8012142577359969,
 12: 0.7601949154628012,
 13: 0.7766900890545142,
 14: 0.7643033596837945,
 15: 0.7813356835095966,
 16: 0.7806752608962555,
 17: 0.7927896351774306,
 18: 0.7899172087522176,
 19: 0.8006138735420503,
 20: 0.8277407810511169,
 21: 0.8113244466185643,
 22: 0.81834451901566,
 23: 0.7457826887661141,
 24: 0.7543319214478243,
 25: 0.7962446141793968}

ft = {1: 0.8756401774118454,
 2: 0.8963000802743923,
 3: 0.893618188133352,
 4: 0.8782995956370399,
 5: 0.8734437171094853,
 6: 0.8560107618931148,
 7: 0.8358450341836359,
 8: 0.8120683589772075,
 9: 0.8073042191882147,
 10: 0.8020453381226585,
 11: 0.7846446105642315,
 12: 0.7733756729266417,
 13: 0.7893774703557311,
 14: 0.7817082893004802,
 15: 0.80798594689548,
 16: 0.8257211538461539,
 17: 0.7828035934992343,
 18: 0.8129733248981947,
 19: 0.8504604051565376,
 20: 0.823494473869516,
 21: 0.8831583136882712,
 22: 0.8711205528288526,
 23: 0.7465808875787183,
 24: 0.7311541151206471,
 25: 0.8111535448491971}

n_ft_age = {1: 0.7419556250462026,
 2: 0.7262285620067374,
 3: 0.7173426044393786,
 4: 0.691635538033843,
 5: 0.6398179690076152,
 6: 0.6593887222528593,
 7: 0.6242575499587936,
 8: 0.6150290075662322,
 9: 0.6159961424034703,
 10: 0.587775849243739,
 11: 0.610801531914659,
 12: 0.6179747102769199,
 13: 0.6129506671625103,
 14: 0.5801262612856816,
 15: 0.5908011252228734,
 16: 0.6043327819887551,
 17: 0.6174998293199131,
 18: 0.6149949446897559,
 19: 0.6494656810479477,
 20: 0.6509944412022349,
 21: 0.7280685900151508,
 22: 0.6733002212778513,
 23: 0.5550794823405364,
 24: 0.5818556887699012,
 25: 0.6615973726826867}

ft_age = {1: 0.7053295024800654,
 2: 0.7078831578201848,
 3: 0.7036576521957626,
 4: 0.708778328880261,
 5: 0.661986726145142,
 6: 0.6689360123018032,
 7: 0.6450298472053911,
 8: 0.6295205230187589,
 9: 0.6352097027478291,
 10: 0.6349222055883444,
 11: 0.6324125192845802,
 12: 0.59587845073281,
 13: 0.6068575236969019,
 14: 0.594302501990451,
 15: 0.5574209105558593,
 16: 0.5862752504056852,
 17: 0.5994668563663991,
 18: 0.5755100731646129,
 19: 0.608041464696431,
 20: 0.6166896120036035,
 21: 0.6148007837691399,
 22: 0.5946921644073068,
 23: 0.5630080141862267,
 24: 0.5510373939670531,
 25: 0.5625568091987229}

n_ft_d = {1: 0.7310413737996224,
 2: 0.7252591440123041,
 3: 0.7084645373300836,
 4: 0.6954856174816803,
 5: 0.7204845779217296,
 6: 0.691331170736205,
 7: 0.6892166904292183,
 8: 0.653625220264392,
 9: 0.6863528727971233,
 10: 0.6501539715994165,
 11: 0.6612683132139305,
 12: 0.6290134136219768,
 13: 0.6449607167266236,
 14: 0.6372013893016077,
 15: 0.6339760541897919,
 16: 0.654259324102158,
 17: 0.6463188930269599,
 18: 0.6534824548599878,
 19: 0.645598666043564,
 20: 0.6802289252338167,
 21: 0.6786609001949239,
 22: 0.6867477838041556,
 23: 0.6094180249502945,
 24: 0.60633056279608,
 25: 0.6560821898884268}

ft_d = {1: 0.7404827747454307,
 2: 0.7273356407609679,
 3: 0.7135129409463941,
 4: 0.6796781119766346,
 5: 0.7003028329148704,
 6: 0.6878255338996329,
 7: 0.6834454390574517,
 8: 0.6755773754056418,
 9: 0.6535704690272235,
 10: 0.6273594664899013,
 11: 0.6306182740200947,
 12: 0.6281262722172316,
 13: 0.6203109124161755,
 14: 0.6234920233275496,
 15: 0.6342084464713491,
 16: 0.6202647938567977,
 17: 0.6000363608421104,
 18: 0.6301106737111088,
 19: 0.6257562138919239,
 20: 0.5705374895130864,
 21: 0.5594917012063675,
 22: 0.5601006879822672,
 23: 0.5478886451806344,
 24: 0.5454340246912044,
 25: 0.5409260184918929}


to_graph = pd.DataFrame.from_dict(n_ft, orient='index', columns = ['w2v-gen'])
to_graph['w2v-age'] = n_ft_age.values()
to_graph['w2v-dial'] = n_ft_d.values()
to_graph['w2v-ru-gen'] = ft.values()
to_graph['w2v-ru-age'] = ft_age.values()
to_graph['w2v-ru-dial'] = ft_d.values()

gfg = sns.lineplot(data=to_graph, palette=['#8cb369', '#8cb369', '#8cb369', '#493c67', '#493c67', '#493c67'])
sns.set_theme()
gfg.set(xlabel ="Layer", ylabel = "F1")
plt.savefig('rq3_summary.png')
